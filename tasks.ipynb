# %% [markdown]
# <div style="text-align: center; margin-bottom: 40px; margin-top: 0;">
#     <img src="./pics/sage-logo.jpg" alt="SAGE Logo" style="width: 200px; margin-top: 20px;">
#     <img src="./pics/ndp-logo.png" alt="NDP Logo" style="width: 130px; height: 100px; margin-top: 20px; margin-left: 100px;">
# </div>
#
# <h1 style="text-align: center; font-size: 48px; margin-top: 0;">Tasks</h1>

# %% [markdown]
# Browse the [Sage portal](https://portal.sagecontinuum.org/nodes) and choose a new node. After choosing a different node, complete the following tasks:

# %% [markdown]
# 1. Map the node location

# %%
# Your code here

# %% [markdown]
# 2. Prepare your data. Make sure to use the right time zone.

# %%
# Your code here

# %% [markdown]
# 3. Perform the window analysis and compare if your results are consistent with the lessons presented in the previous notebook.

# %%
# Your code here

# %% [markdown]
#  4. Compute the vapor-pressure deficit, $\mathrm{VPD} = e_s(T) - e$

# %%
# Your code here
